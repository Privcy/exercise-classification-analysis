# %%
DATA_DIR = r"D:\Final Thesis\freshPoseModel\tsfilesOpenPose"

# %%
#!git clone https://github.com/mlgig/BodyMTS_2021.git
# Out:
# ^C
# Cloning into 'BodyMTS_2021'...
# Updating files:  27% (17/62)
# Updating files:  29% (18/62)
# Updating files:  30% (19/62)
# Updating files:  32% (20/62)
# Updating files:  33% (21/62)
# Updating files:  35% (22/62)
# Updating files:  37% (23/62)
# Updating files:  38% (24/62)
# Updating files:  40% (25/62)
# Updating files:  41% (26/62)
# Updating files:  43% (27/62)
# Updating files:  45% (28/62)
# Updating files:  46% (29/62)
# Updating files:  48% (30/62)
# Updating files:  50% (31/62)
# Updating files:  51% (32/62)
# Updating files:  53% (33/62)
# Updating files:  54% (34/62)
# Updating files:  56% (35/62)
# Updating files:  58% (36/62)
# Updating files:  59% (37/62)
# Updating files:  61% (38/62)
# Updating files:  62% (39/62)
# Updating files:  64% (40/62)
# Updating files:  66% (41/62)
# Updating files:  67% (42/62)
# Updating files:  69% (43/62)
# Updating files:  70% (44/62)
# Updating files:  72% (45/62)
# Updating files:  74% (46/62)
# Updating files:  75% (47/62)
# ...
